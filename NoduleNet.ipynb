# %% [markdown]
# <a href="https://colab.research.google.com/github/SnehaShukla937/ComputerVision_OpenCV/blob/master/NoduleNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/uci-cbcl/NoduleNet.git
# Out:
# fatal: destination path 'NoduleNet' already exists and is not an empty directory.

# %%
# !wget https://wiki.cancerimagingarchive.net/download/attachments/1966254/LIDC-XML-only.zip?version=1&modificationDate=1530215018015&api=v2
# Out:
# --2021-01-28 14:53:53--  https://wiki.cancerimagingarchive.net/download/attachments/1966254/LIDC-XML-only.zip?version=1
# Resolving wiki.cancerimagingarchive.net (wiki.cancerimagingarchive.net)... 144.30.169.13
# Connecting to wiki.cancerimagingarchive.net (wiki.cancerimagingarchive.net)|144.30.169.13|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 9034311 (8.6M) [application/zip]
# Saving to: ‘LIDC-XML-only.zip?version=1’
#
# LIDC-XML-only.zip?v 100%[===================>]   8.62M  20.6MB/s    in 0.4s
#
# Last-modified header invalid -- time-stamp ignored.
# 2021-01-28 14:53:54 (20.6 MB/s) - ‘LIDC-XML-only.zip?version=1’ saved [9034311/9034311]

# %%
# !unzip LIDC-XML-only.zip
# !rm -rf LIDC-XML-only.zip
# Out:
# Archive:  LIDC-XML-only.zip
#   inflating: 161-resubmitted-correction-3-9-12.xml
#    creating: tcia-lidc-xml/
#    creating: tcia-lidc-xml/157/
#   inflating: tcia-lidc-xml/157/158.xml
#   inflating: tcia-lidc-xml/157/159.xml
#   inflating: tcia-lidc-xml/157/160.xml
#   inflating: tcia-lidc-xml/157/161.xml
#   inflating: tcia-lidc-xml/157/162.xml
#   inflating: tcia-lidc-xml/157/163.xml
#   inflating: tcia-lidc-xml/157/164.xml
#   inflating: tcia-lidc-xml/157/165.xml
#   inflating: tcia-lidc-xml/157/166.xml
#   inflating: tcia-lidc-xml/157/167.xml
#   inflating: tcia-lidc-xml/157/168.xml
#    creating: tcia-lidc-xml/185/
#   inflating: tcia-lidc-xml/185/068.xml
#   inflating: tcia-lidc-xml/185/069.xml
#   inflating: tcia-lidc-xml/185/070.xml
#   inflating: tcia-lidc-xml/185/071.xml
#   inflating: tcia-lidc-xml/185/072.xml
#   inflating: tcia-lidc-xml/185/073.xml
#   inflating: tcia-lidc-xml/185/074.xml
#   inflating: tcia-lidc-xml/185/075.xml
# ...

# %%
# !wget https://zenodo.org/record/3723295/files/subset0.zip?download=1
# Out:
# --2021-01-28 14:55:02--  https://zenodo.org/record/3723295/files/subset0.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6811924508 (6.3G) [application/octet-stream]
# Saving to: ‘subset0.zip?download=1’
#
# subset0.zip?downloa 100%[===================>]   6.34G  5.40MB/s    in 12m 5s
#
# 2021-01-28 15:07:08 (8.97 MB/s) - ‘subset0.zip?download=1’ saved [6811924508/6811924508]

# %%
# !wget https://zenodo.org/record/3723295/files/subset1.zip?download=1
# Out:
# --2021-01-28 15:07:08--  https://zenodo.org/record/3723295/files/subset1.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6334778552 (5.9G) [application/octet-stream]
# Saving to: ‘subset1.zip?download=1’
#
# subset1.zip?downloa 100%[===================>]   5.90G  10.2MB/s    in 11m 21s
#
# 2021-01-28 15:18:30 (8.87 MB/s) - ‘subset1.zip?download=1’ saved [6334778552/6334778552]

# %%
# !wget https://zenodo.org/record/3723295/files/subset3.zip?download=1
# Out:
# --2021-01-28 15:18:30--  https://zenodo.org/record/3723295/files/subset3.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6896620114 (6.4G) [application/octet-stream]
# Saving to: ‘subset3.zip?download=1’
#
# subset3.zip?downloa 100%[===================>]   6.42G  11.1MB/s    in 11m 16s
#
# 2021-01-28 15:29:48 (9.73 MB/s) - ‘subset3.zip?download=1’ saved [6896620114/6896620114]

# %%
# !wget https://zenodo.org/record/3723295/files/subset2.zip?download=1
# !wget https://zenodo.org/record/3723295/files/subset4.zip?download=1
# !wget https://zenodo.org/record/3723295/files/subset5.zip?download=1
# Out:
# --2021-01-28 15:29:48--  https://zenodo.org/record/3723295/files/subset2.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7257937108 (6.8G) [application/octet-stream]
# Saving to: ‘subset2.zip?download=1’
#
# subset2.zip?downloa 100%[===================>]   6.76G  20.2MB/s    in 9m 57s
#
# utime(subset2.zip?download=1): No such file or directory
# 2021-01-28 15:39:46 (11.6 MB/s) - ‘subset2.zip?download=1’ saved [7257937108/7257937108]
#
# --2021-01-28 15:39:46--  https://zenodo.org/record/3723295/files/subset4.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6856144330 (6.4G) [application/octet-stream]
# Saving to: ‘subset4.zip?download=1’
#
# ...

# %%
# !wget https://zenodo.org/record/3723295/files/subset6.zip?download=1
# !wget https://zenodo.org/record/4121926/files/subset7.zip?download=1
# !wget https://zenodo.org/record/4121926/files/subset8.zip?download=1
# !wget https://zenodo.org/record/4121926/files/subset9.zip?download=1
# Out:
# --2021-01-28 15:58:24--  https://zenodo.org/record/3723295/files/subset6.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6531050274 (6.1G) [application/octet-stream]
# Saving to: ‘subset6.zip?download=1’
#
# subset6.zip?downloa 100%[===================>]   6.08G  5.78MB/s    in 11m 29s
#
# 2021-01-28 16:09:55 (9.04 MB/s) - ‘subset6.zip?download=1’ saved [6531050274/6531050274]
#
# --2021-01-28 16:09:55--  https://zenodo.org/record/4121926/files/subset7.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6313598213 (5.9G) [application/octet-stream]
# Saving to: ‘subset7.zip?download=1’
#
# subset7.zip?downloa 100%[===================>]   5.88G  12.7MB/s    in 10m 56s
#
# ...

# %%
# !wget https://zenodo.org/record/3723295/files/seg-lungs-LUNA16.zip?download=1
# Out:
# --2021-01-28 16:42:51--  https://zenodo.org/record/3723295/files/seg-lungs-LUNA16.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 303871549 (290M) [application/octet-stream]
# Saving to: ‘seg-lungs-LUNA16.zip?download=1’
#
# seg-lungs-LUNA16.zi 100%[===================>] 289.79M  21.2MB/s    in 13s
#
# 2021-01-28 16:43:06 (21.9 MB/s) - ‘seg-lungs-LUNA16.zip?download=1’ saved [303871549/303871549]

# %%
# !unzip seg-lungs-LUNA16.zip
# Out:
# Archive:  seg-lungs-LUNA16.zip
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.mhd
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.zraw
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100332161840553388986847034053.mhd
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100332161840553388986847034053.zraw
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793540579077826395208.mhd
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793540579077826395208.zraw
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100530488926682752765845212286.mhd
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100530488926682752765845212286.zraw
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100620385482151095585000946543.mhd
# ...

# %%
# !rm -rf seg-lungs-LUNA16.zip

# %%
# !mv "/content/subset9.zip" "/content/NoduleNet/data/LIDC/combined/"

# %%
# !python3 /content/NoduleNet/utils/LIDC/preprocess.py
# Out:
# nod mask dir /content/NoduleNet/data/LIDC/masks_test/3
# save dir  /content/NoduleNet/data/LIDC/preprocessed_test/3

# %%
# !pip3 install http.client
# Out:
# ...
#      |████████████████████████████████| 225kB 6.0MB/s
# ...
#   Created wheel for http.client: filename=http_client-0.1.22-cp36-none-any.whl size=2210 sha256=d8a52f2617b3ae00467096562e7c28e0bd54d00ddd4bf1d6a419c3daa20427ce
#   Stored in directory: /root/.cache/pip/wheels/36/24/3b/9baa50c4824de1cf6697ee4226ec19f07fab94a65208834234
# ...
#   Created wheel for pycurl: filename=pycurl-7.43.0.6-cp36-cp36m-linux_x86_64.whl size=284435 sha256=7ccca6aa3c767ef4772a553a6bfc6025b4e16494ffe3e125356230e19e2150cb
#   Stored in directory: /root/.cache/pip/wheels/d9/a1/7b/2894883fd5c69a3ba684a49d255466d1e924b3cf58cedc1ade
# Successfully built http.client pycurl
# ...

# %%
# !python3 /content/NoduleNet/train.py
# Out:
# ...
# Traceback (most recent call last):
#   File "/content/NoduleNet/net/layer/rpn_nms.py", line 8, in <module>
#     from utils.pybox import *
#   File "/content/NoduleNet/utils/pybox.py", line 3, in <module>
#     from box import cpu_nms, cpu_overlap
#   File "/usr/local/lib/python3.6/dist-packages/box/__init__.py", line 1, in <module>
#     from .client import BoxClient, \
#   File "/usr/local/lib/python3.6/dist-packages/box/client.py", line 7, in <module>
#     from httplib import NOT_FOUND, PRECONDITION_FAILED, CONFLICT, UNAUTHORIZED
# ModuleNotFoundError: No module named 'httplib'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/NoduleNet/train.py", line 1, in <module>
#     from net.nodule_net import NoduleNet
#   File "/content/NoduleNet/net/nodule_net.py", line 3, in <module>
#     from net.layer import *
#   File "/content/NoduleNet/net/layer/__init__.py", line 1, in <module>
# ...
